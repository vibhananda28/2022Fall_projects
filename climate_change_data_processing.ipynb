# %% [markdown]
# ### This notebook contains the code relevant for data cleaning and processing. It also includes some basic plots and summary statistics.

# %%
# %matplotlib inline

import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import climate_change_util as cc #Importing util file with functions as module

# %% [markdown]
# ##### Reading and cleaning the OECD dataset

# %%
oecd = pd.read_csv('./Data/MUNW_27112022020812290.csv', usecols=[0,1,3,5,7,9,11,12,14])

# %% [markdown]
# ##### Cleaning and reshaping using the functions created in the climate_change_util script

# %%
oecd = cc.clean_data(oecd,['Country','Variable'])

# %%
oecd.head()
# Out:
#    COU    Country                   Variable  Year    Unit  PowerCode  \
# 0  AUS  Australia  Municipal waste generated  1992  Tonnes  Thousands
# 1  AUS  Australia  Municipal waste generated  2000  Tonnes  Thousands
# 2  AUS  Australia  Municipal waste generated  2007  Tonnes  Thousands
# 3  AUS  Australia  Municipal waste generated  2008  Tonnes  Thousands
# 4  AUS  Australia  Municipal waste generated  2009  Tonnes  Thousands
#
#   Reference Period      Value            Flags
# 0              NaN  12000.000              NaN
# 1              NaN  13200.000              NaN
# 2              NaN  12885.684              NaN
# 3              NaN  13096.500  Estimated value
# 4              NaN  13343.236              NaN

# %%
oecd_reshaped = cc.long_to_wide(oecd,['Year','COU','Country'],'Variable','Value',['Country', 'Year'])

# %%
oecd_reshaped.head()
# Out:
# Variable                               % Composting  % Disposal  \
# Year COU Country
# 1990 AUT Austria                             23.171      56.277
#      BEL Belgium                              5.983      66.751
#      CHE Switzerland                          6.341      22.680
#      CHN China (People's Republic of)           NaN         NaN
#      DEU Germany                                NaN         NaN
#
# Variable                               % Incineration  \
# Year COU Country
# 1990 AUT Austria                                8.881
#      BEL Belgium                               45.039
#      CHE Switzerland                           48.773
#      CHN China (People's Republic of)             NaN
#      DEU Germany                                  NaN
#
# Variable                               % Incineration with energy recovery  \
# Year COU Country
# 1990 AUT Austria                                                     8.881
#      BEL Belgium                                                    22.141
#      CHE Switzerland                                                48.773
#      CHN China (People's Republic of)                                  NaN
#      DEU Germany                                                       NaN
#
# Variable                               % Incineration without energy recovery  \
# Year COU Country
# 1990 AUT Austria                                                          NaN
#      BEL Belgium                                                       22.898
#      CHE Switzerland                                                    0.000
#      CHN China (People's Republic of)                                     NaN
#      DEU Germany                                                          NaN
#
# Variable                               % Landfill  \
# Year COU Country
# 1990 AUT Austria                           56.277
#      BEL Belgium                           43.853
#      CHE Switzerland                       22.680
#      CHN China (People's Republic of)         NaN
#      DEU Germany                              NaN
#
# Variable                               % Material recovery (Recycling + Composting)  \
# Year COU Country
# 1990 AUT Austria                                                             34.529
#      BEL Belgium                                                             11.108
#      CHE Switzerland                                                         28.547
#      CHN China (People's Republic of)                                           NaN
#      DEU Germany                                                                NaN
#
# Variable                               % Other disposal  % Other recovery  \
# Year COU Country
# 1990 AUT Austria                                    NaN             0.313
#      BEL Belgium                                    NaN               NaN
#      CHE Switzerland                                NaN               NaN
#      CHN China (People's Republic of)               NaN               NaN
#      DEU Germany                                    NaN               NaN
#
# Variable                               % Recovery  ...  \
# Year COU Country                                   ...
# 1990 AUT Austria                           43.723  ...
#      BEL Belgium                           33.249  ...
#      CHE Switzerland                       77.320  ...
#      CHN China (People's Republic of)         NaN  ...
#      DEU Germany                              NaN  ...
#
# Variable                               Municipal waste generated per capita  \
# Year COU Country
# 1990 AUT Austria                                                    414.814
#      BEL Belgium                                                    343.375
#      CHE Switzerland                                                616.366
#      CHN China (People's Republic of)                                   NaN
#      DEU Germany                                                    630.670
#
# Variable                               Municipal waste generated, Index 1990  \
# Year COU Country
# 1990 AUT Austria                                                       100.0
#      BEL Belgium                                                       100.0
#      CHE Switzerland                                                   100.0
#      CHN China (People's Republic of)                                  100.0
#      DEU Germany                                                       100.0
#
# Variable                               Municipal waste generated, Index 2000  \
# Year COU Country
# 1990 AUT Austria                                                      68.963
#      BEL Belgium                                                      71.131
#      CHE Switzerland                                                  86.675
#      CHN China (People's Republic of)                                 57.254
#      DEU Germany                                                      94.408
#
# Variable                               Municipal waste treated  \
# Year COU Country
# 1990 AUT Austria                                        3513.0
#      BEL Belgium                                        3961.0
#      CHE Switzerland                                    4100.6
#      CHN China (People's Republic of)                      NaN
#      DEU Germany                                           NaN
#
# Variable                               Other disposal  Other municipal waste  \
# Year COU Country
# 1990 AUT Austria                                  NaN                  700.0
#      BEL Belgium                                  NaN                  552.0
#      CHE Switzerland                              NaN                 1681.0
#      CHN China (People's Republic of)             NaN                    NaN
#      DEU Germany                                  NaN                    NaN
#
# Variable                               Other recovery  Recycling  \
# Year COU Country
# 1990 AUT Austria                                 11.0      399.0
#      BEL Belgium                                  NaN      203.0
#      CHE Switzerland                              NaN      910.6
#      CHN China (People's Republic of)             NaN        NaN
#      DEU Germany                                  NaN        NaN
#
# Variable                               Total Incineration  \
# Year COU Country
# 1990 AUT Austria                                    312.0
#      BEL Belgium                                   1784.0
#      CHE Switzerland                               2000.0
#      CHN China (People's Republic of)                 NaN
#      DEU Germany                                      NaN
#
# Variable                               Waste from households
# Year COU Country
# 1990 AUT Austria                                      2504.0
#      BEL Belgium                                      2884.0
#      CHE Switzerland                                  2733.7
#      CHN China (People's Republic of)                    NaN
#      DEU Germany                                         NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ###### Convert the pivot table to dataframe

# %%
oecd_final = pd.DataFrame(oecd_reshaped.to_records())
oecd_final.tail()
# Out:
#       Year  COU          Country  % Composting  % Disposal  % Incineration  \
# 1195  2020  POL           Poland        12.030      41.047             NaN
# 1196  2020  PRT         Portugal        14.289      53.455             NaN
# 1197  2020  SVK  Slovak Republic        13.720      49.755             NaN
# 1198  2020  SVN         Slovenia        18.142      11.023             NaN
# 1199  2020  SWE           Sweden        18.262       0.475             NaN
#
#       % Incineration with energy recovery  \
# 1195                               20.250
# 1196                               18.979
# 1197                                7.952
# 1198                               13.970
# 1199                               60.597
#
#       % Incineration without energy recovery  % Landfill  \
# 1195                                   1.269      39.779
# 1196                                   0.000      53.455
# 1197                                   0.004      49.751
# 1198                                   2.544       8.479
# 1199                                   0.000       0.427
#
#       % Material recovery (Recycling + Composting)  ...  \
# 1195                                        38.702  ...
# 1196                                        27.566  ...
# 1197                                        42.287  ...
# 1198                                        74.958  ...
# 1199                                        38.576  ...
#
#       Municipal waste generated per capita  \
# 1195                               346.581
# 1196                               517.667
# 1197                               433.292
# 1198                               492.600
# 1199                               441.597
#
#       Municipal waste generated, Index 1990  \
# 1195                                118.192
# 1196                                175.950
# 1197                                    NaN
# 1198                                    NaN
# 1199                                139.369
#
#       Municipal waste generated, Index 2000  Municipal waste treated  \
# 1195                                107.287                13116.898
# 1196                                112.200                 5070.835
# 1197                                172.838                 2361.663
# 1198                                100.400                  808.953
# 1199                                118.203                 4422.317
#
#       Other disposal  Other municipal waste  Other recovery  Recycling  \
# 1195             NaN               1828.615             NaN   3498.629
# 1196           0.000                  0.000           0.000    673.228
# 1197           0.000               1029.008           0.147    674.654
# 1198           0.000                395.637           0.000    459.605
# 1199           2.092                684.280          14.219    898.350
#
#       Total Incineration  Waste from households
# 1195                 NaN              11288.283
# 1196                 NaN                  0.000
# 1197                 NaN               1336.614
# 1198                 NaN                628.439
# 1199                 NaN               3775.526
#
# [5 rows x 34 columns]

# %% [markdown]
# ##### Reading and cleaning the World Bank's WDI dataset

# %%
wdi = pd.read_csv('./Data/Data.csv')

# %%
wdi = wdi.drop(['Series Code'],axis=1)

# %%
wdi_clean = cc.clean_data(wdi,['Country Name','Series Name'])

# %%
wdi_long = cc.wide_to_long(wdi_clean,"YR",["index","Country Name","Country Code"],"Year",["Country Code", "Country Name", "Year",\
                                                                                          "Series Name", "YR"])

# %%
wdi_long.head()
# Out:
#   Country Code Country Name  Year                             Series Name   YR
# 0          ARG    Argentina  1980  CO2 emissions (metric tons per capita)  NaN
# 1          ARG    Argentina  1981  CO2 emissions (metric tons per capita)  NaN
# 2          ARG    Argentina  1982  CO2 emissions (metric tons per capita)  NaN
# 3          ARG    Argentina  1983  CO2 emissions (metric tons per capita)  NaN
# 4          ARG    Argentina  1984  CO2 emissions (metric tons per capita)  NaN

# %%
wdi_reshaped = cc.long_to_wide(wdi_long,['Year','Country Code','Country Name'],'Series Name','YR',['Year','Country Name'])

# %%
wdi_reshaped.head()
# Out:
# Series Name                                   CO2 emissions (metric tons per capita)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                          NaN
#      AFE          Africa Eastern and Southern                                    NaN
#      AFG          Afghanistan                                                    NaN
#      AFW          Africa Western and Central                                     NaN
#      AGO          Angola                                                         NaN
#
# Series Name                                   Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Energy use (kg of oil equivalent per capita)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                NaN
#      AFE          Africa Eastern and Southern                             789.384320528797
#      AFG          Afghanistan                                                          NaN
#      AFW          Africa Western and Central                              569.830665834955
#      AGO          Angola                                                  547.044521890499
#
# Series Name                                   Forest area (sq. km)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                        NaN
#      AFE          Africa Eastern and Southern                  NaN
#      AFG          Afghanistan                                  NaN
#      AFW          Africa Western and Central                   NaN
#      AGO          Angola                                       NaN
#
# Series Name                                   GDP (constant 2015 US$)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                           NaN
#      AFE          Africa Eastern and Southern        333894467085.439
#      AFG          Afghanistan                                     NaN
#      AFW          Africa Western and Central         245386033779.559
#      AGO          Angola                             22133386922.5976
#
# Series Name                                   GDP growth (annual %)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                         NaN
#      AFE          Africa Eastern and Southern      5.41938159928385
#      AFG          Afghanistan                                   NaN
#      AFW          Africa Western and Central       1.99542065752085
#      AGO          Angola                                        NaN
#
# Series Name                                   GDP per capita (constant 2015 US$)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                      NaN
#      AFE          Africa Eastern and Southern                   1468.92096062617
#      AFG          Afghanistan                                                NaN
#      AFW          Africa Western and Central                    1574.17539390181
#      AGO          Angola                                        2653.47289479177
#
# Series Name                                   GDP per capita growth (annual %)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                    NaN
#      AFE          Africa Eastern and Southern                 2.37442217038561
#      AFG          Afghanistan                                              NaN
#      AFW          Africa Western and Central                 -0.76473427494092
#      AGO          Angola                                                   NaN
#
# Series Name                                    ...  \
# Year Country Code Country Name                 ...
# 1980 ABW          Aruba                        ...
#      AFE          Africa Eastern and Southern  ...
#      AFG          Afghanistan                  ...
#      AFW          Africa Western and Central   ...
#      AGO          Angola                       ...
#
# Series Name                                   Government expenditure on education, total (% of government expenditure)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Population density (people per sq. km of land area)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                         333.872222222222
#      AFE          Africa Eastern and Southern                                   15.5992323017681
#      AFG          Afghanistan                                                   20.4782055409901
#      AFW          Africa Western and Central                                    17.2325957518312
#      AGO          Angola                                                        6.69069543595091
#
# Series Name                                   Population growth (annual %)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                  0.208213685729551
#      AFE          Africa Eastern and Southern             2.97433613234995
#      AFG          Afghanistan                           -0.407658191922243
#      AFW          Africa Western and Central              2.78142544618063
#      AGO          Angola                                  3.45385947653688
#
# Series Name                                   Population, female  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                    30806
#      AFE          Africa Eastern and Southern          114440574
#      AFG          Afghanistan                            6568227
#      AFW          Africa Western and Central            78003993
#      AGO          Angola                                 4115191
#
# Series Name                                   Population, female (% of total population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                 51.2604622526915
#      AFE          Africa Eastern and Southern                           50.3464941930698
#      AFG          Afghanistan                                           49.1762587504211
#      AFW          Africa Western and Central                            50.0403240214554
#      AGO          Angola                                                 49.335186763678
#
# Series Name                                   Population, total  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                   60097
#      AFE          Africa Eastern and Southern         227305945
#      AFG          Afghanistan                          13356500
#      AFW          Africa Western and Central          155882270
#      AGO          Angola                                8341290
#
# Series Name                                   Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Poverty headcount ratio at national poverty lines (% of population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Urban population (% of total population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                         50.472
#      AFE          Africa Eastern and Southern                         20.8449997980123
#      AFG          Afghanistan                                                   15.995
#      AFW          Africa Western and Central                          24.5185774336299
#      AGO          Angola                                                        24.298
#
# Series Name                                   Urban population growth (annual %)
# Year Country Code Country Name
# 1980 ABW          Aruba                                        0.178188464900201
#      AFE          Africa Eastern and Southern                   4.45422064112357
#      AFG          Afghanistan                                   3.11083842471923
#      AFW          Africa Western and Central                    4.89701529375728
#      AGO          Angola                                        8.11256004063561
#
# [5 rows x 21 columns]

# %%
wdi_reshaped = wdi_reshaped.rename({'Country Code': 'COU'})
wdi_reshaped.head()
# Out:
# Series Name                                   CO2 emissions (metric tons per capita)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                          NaN
#      AFE          Africa Eastern and Southern                                    NaN
#      AFG          Afghanistan                                                    NaN
#      AFW          Africa Western and Central                                     NaN
#      AGO          Angola                                                         NaN
#
# Series Name                                   Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Energy use (kg of oil equivalent per capita)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                NaN
#      AFE          Africa Eastern and Southern                             789.384320528797
#      AFG          Afghanistan                                                          NaN
#      AFW          Africa Western and Central                              569.830665834955
#      AGO          Angola                                                  547.044521890499
#
# Series Name                                   Forest area (sq. km)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                        NaN
#      AFE          Africa Eastern and Southern                  NaN
#      AFG          Afghanistan                                  NaN
#      AFW          Africa Western and Central                   NaN
#      AGO          Angola                                       NaN
#
# Series Name                                   GDP (constant 2015 US$)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                           NaN
#      AFE          Africa Eastern and Southern        333894467085.439
#      AFG          Afghanistan                                     NaN
#      AFW          Africa Western and Central         245386033779.559
#      AGO          Angola                             22133386922.5976
#
# Series Name                                   GDP growth (annual %)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                         NaN
#      AFE          Africa Eastern and Southern      5.41938159928385
#      AFG          Afghanistan                                   NaN
#      AFW          Africa Western and Central       1.99542065752085
#      AGO          Angola                                        NaN
#
# Series Name                                   GDP per capita (constant 2015 US$)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                      NaN
#      AFE          Africa Eastern and Southern                   1468.92096062617
#      AFG          Afghanistan                                                NaN
#      AFW          Africa Western and Central                    1574.17539390181
#      AGO          Angola                                        2653.47289479177
#
# Series Name                                   GDP per capita growth (annual %)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                    NaN
#      AFE          Africa Eastern and Southern                 2.37442217038561
#      AFG          Afghanistan                                              NaN
#      AFW          Africa Western and Central                 -0.76473427494092
#      AGO          Angola                                                   NaN
#
# Series Name                                    ...  \
# Year Country Code Country Name                 ...
# 1980 ABW          Aruba                        ...
#      AFE          Africa Eastern and Southern  ...
#      AFG          Afghanistan                  ...
#      AFW          Africa Western and Central   ...
#      AGO          Angola                       ...
#
# Series Name                                   Government expenditure on education, total (% of government expenditure)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Population density (people per sq. km of land area)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                         333.872222222222
#      AFE          Africa Eastern and Southern                                   15.5992323017681
#      AFG          Afghanistan                                                   20.4782055409901
#      AFW          Africa Western and Central                                    17.2325957518312
#      AGO          Angola                                                        6.69069543595091
#
# Series Name                                   Population growth (annual %)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                  0.208213685729551
#      AFE          Africa Eastern and Southern             2.97433613234995
#      AFG          Afghanistan                           -0.407658191922243
#      AFW          Africa Western and Central              2.78142544618063
#      AGO          Angola                                  3.45385947653688
#
# Series Name                                   Population, female  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                    30806
#      AFE          Africa Eastern and Southern          114440574
#      AFG          Afghanistan                            6568227
#      AFW          Africa Western and Central            78003993
#      AGO          Angola                                 4115191
#
# Series Name                                   Population, female (% of total population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                 51.2604622526915
#      AFE          Africa Eastern and Southern                           50.3464941930698
#      AFG          Afghanistan                                           49.1762587504211
#      AFW          Africa Western and Central                            50.0403240214554
#      AGO          Angola                                                 49.335186763678
#
# Series Name                                   Population, total  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                   60097
#      AFE          Africa Eastern and Southern         227305945
#      AFG          Afghanistan                          13356500
#      AFW          Africa Western and Central          155882270
#      AGO          Angola                                8341290
#
# Series Name                                   Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Poverty headcount ratio at national poverty lines (% of population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                                      NaN
#      AFE          Africa Eastern and Southern                                                NaN
#      AFG          Afghanistan                                                                NaN
#      AFW          Africa Western and Central                                                 NaN
#      AGO          Angola                                                                     NaN
#
# Series Name                                   Urban population (% of total population)  \
# Year Country Code Country Name
# 1980 ABW          Aruba                                                         50.472
#      AFE          Africa Eastern and Southern                         20.8449997980123
#      AFG          Afghanistan                                                   15.995
#      AFW          Africa Western and Central                          24.5185774336299
#      AGO          Angola                                                        24.298
#
# Series Name                                   Urban population growth (annual %)
# Year Country Code Country Name
# 1980 ABW          Aruba                                        0.178188464900201
#      AFE          Africa Eastern and Southern                   4.45422064112357
#      AFG          Afghanistan                                   3.11083842471923
#      AFW          Africa Western and Central                    4.89701529375728
#      AGO          Angola                                        8.11256004063561
#
# [5 rows x 21 columns]

# %% [markdown]
# ###### Convert the pivot table to dataframe

# %%
wdi_final = pd.DataFrame(wdi_reshaped.to_records())

# %%
wdi_final.head()
# Out:
#    Year Country Code                 Country Name  \
# 0  1980          ABW                        Aruba
# 1  1980          AFE  Africa Eastern and Southern
# 2  1980          AFG                  Afghanistan
# 3  1980          AFW   Africa Western and Central
# 4  1980          AGO                       Angola
#
#   CO2 emissions (metric tons per capita)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Energy use (kg of oil equivalent per capita) Forest area (sq. km)  \
# 0                                          NaN                  NaN
# 1                             789.384320528797                  NaN
# 2                                          NaN                  NaN
# 3                             569.830665834955                  NaN
# 4                             547.044521890499                  NaN
#
#   GDP (constant 2015 US$)  ...  \
# 0                     NaN  ...
# 1        333894467085.439  ...
# 2                     NaN  ...
# 3        245386033779.559  ...
# 4        22133386922.5976  ...
#
#   Government expenditure on education, total (% of government expenditure)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population density (people per sq. km of land area)  \
# 0                                   333.872222222222
# 1                                   15.5992323017681
# 2                                   20.4782055409901
# 3                                   17.2325957518312
# 4                                   6.69069543595091
#
#   Population growth (annual %) Population, female  \
# 0            0.208213685729551              30806
# 1             2.97433613234995          114440574
# 2           -0.407658191922243            6568227
# 3             2.78142544618063           78003993
# 4             3.45385947653688            4115191
#
#   Population, female (% of total population) Population, total  \
# 0                           51.2604622526915             60097
# 1                           50.3464941930698         227305945
# 2                           49.1762587504211          13356500
# 3                           50.0403240214554         155882270
# 4                            49.335186763678           8341290
#
#   Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Urban population (% of total population) Urban population growth (annual %)
# 0                                   50.472                  0.178188464900201
# 1                         20.8449997980123                   4.45422064112357
# 2                                   15.995                   3.11083842471923
# 3                         24.5185774336299                   4.89701529375728
# 4                                   24.298                   8.11256004063561
#
# [5 rows x 24 columns]

# %% [markdown]
# ###### Rename columns to have names for merging

# %%
wdi_final = wdi_final.rename(columns={'Country Code': 'COU', 'Country Name': 'Country'})

# %%
oecd_final.columns
# Out:
# Index(['Year', 'COU', 'Country', '% Composting', '% Disposal',
#        '% Incineration', '% Incineration with energy recovery',
#        '% Incineration without energy recovery', '% Landfill',
#        '% Material recovery (Recycling + Composting)', '% Other disposal',
#        '% Other recovery', '% Recovery', '% Recycling',
#        'Amount designated for recovery operations', 'Bulky waste',
#        'Composting', 'Disposal operations',
#        'Electric and electronic equipment waste',
#        'Household and similar waste', 'Incineration with energy recovery',
#        'Incineration without energy recovery', 'Landfill',
#        'Municipal waste generated', 'Municipal waste generated per capita',
#        'Municipal waste generated, Index 1990',
#        'Municipal waste generated, Index 2000', 'Municipal waste treated',
#        'Other disposal', 'Other municipal waste', 'Other recovery',
#        'Recycling', 'Total Incineration', 'Waste from households'],
#       dtype='object')

# %%
wdi_final.columns
# Out:
# Index(['Year', 'COU', 'Country', 'CO2 emissions (metric tons per capita)',
#        'Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)',
#        'Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)',
#        'Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)',
#        'Energy use (kg of oil equivalent per capita)', 'Forest area (sq. km)',
#        'GDP (constant 2015 US$)', 'GDP growth (annual %)',
#        'GDP per capita (constant 2015 US$)',
#        'GDP per capita growth (annual %)',
#        'Government expenditure on education, total (% of GDP)',
#        'Government expenditure on education, total (% of government expenditure)',
#        'Population density (people per sq. km of land area)',
#        'Population growth (annual %)', 'Population, female',
#        'Population, female (% of total population)', 'Population, total',
#        'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)',
#        'Poverty headcount ratio at national poverty lines (% of population)',
#        'Urban population (% of total population)',
#        'Urban population growth (annual %)'],
#       dtype='object')

# %% [markdown]
# ###### Merge both dataframes to have one large dataframe for processing.

# %%
merged_df = pd.merge(oecd_final, wdi_final, how='inner', left_on=['Year','COU'], right_on=['Year','COU'])

# %%
merged_df.head()
# Out:
#    Year  COU                     Country_x  % Composting  % Disposal  \
# 0  1990  AUT                       Austria        23.171      56.277
# 1  1990  BEL                       Belgium         5.983      66.751
# 2  1990  CHE                   Switzerland         6.341      22.680
# 3  1990  CHN  China (People's Republic of)           NaN         NaN
# 4  1990  DEU                       Germany           NaN         NaN
#
#    % Incineration  % Incineration with energy recovery  \
# 0           8.881                                8.881
# 1          45.039                               22.141
# 2          48.773                               48.773
# 3             NaN                                  NaN
# 4             NaN                                  NaN
#
#    % Incineration without energy recovery  % Landfill  \
# 0                                     NaN      56.277
# 1                                  22.898      43.853
# 2                                   0.000      22.680
# 3                                     NaN         NaN
# 4                                     NaN         NaN
#
#    % Material recovery (Recycling + Composting)  ...  \
# 0                                        34.529  ...
# 1                                        11.108  ...
# 2                                        28.547  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
#
#    Government expenditure on education, total (% of government expenditure)  \
# 0                                   11.5131101608276
# 1                                                NaN
# 2                                       17.181640625
# 3                                                NaN
# 4                                                NaN
#
#    Population density (people per sq. km of land area)  \
# 0                                   93.0422927775085
# 1                                                NaN
# 2                                   169.888411039996
# 3                                   120.448249116415
# 4                                   227.517053819494
#
#    Population growth (annual %)  Population, female  \
# 0             0.762001611316115             4005232
# 1             0.298235706313592             5090672
# 2              1.02687307219521             3437405
# 3              1.46730321087928           552721134
# 4             0.861969448764933            41104568
#
#    Population, female (% of total population)  Population, total  \
# 0                            52.1660667580361            7677850
# 1                            51.0733225104169            9967379
# 2                            51.1859913754554            6715519
# 3                            48.6899610599665         1135185000
# 4                            51.7474514630407           79433029
#
#    Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                 72
# 4                                                NaN
#
#    Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Urban population (% of total population)  \
# 0                                     62.96
# 1                                    96.377
# 2                                    73.926
# 3                                    26.442
# 4                                    73.118
#
#    Urban population growth (annual %)
# 0                   0.332494357748522
# 1                   0.386473447431904
# 2                   0.945758640258411
# 3                    4.30967848070248
# 4                    1.05636514177316
#
# [5 rows x 56 columns]

# %%
merged_df[['Country_x', 'Country_y']].head()
# Out:
#                       Country_x    Country_y
# 0                       Austria      Austria
# 1                       Belgium      Belgium
# 2                   Switzerland  Switzerland
# 3  China (People's Republic of)        China
# 4                       Germany      Germany

# %%
merged_df.columns.values
# Out:
# array(['Year', 'COU', 'Country_x', '% Composting', '% Disposal',
#        '% Incineration', '% Incineration with energy recovery',
#        '% Incineration without energy recovery', '% Landfill',
#        '% Material recovery (Recycling + Composting)', '% Other disposal',
#        '% Other recovery', '% Recovery', '% Recycling',
#        'Amount designated for recovery operations', 'Bulky waste',
#        'Composting', 'Disposal operations',
#        'Electric and electronic equipment waste',
#        'Household and similar waste', 'Incineration with energy recovery',
#        'Incineration without energy recovery', 'Landfill',
#        'Municipal waste generated',
#        'Municipal waste generated per capita',
#        'Municipal waste generated, Index 1990',
#        'Municipal waste generated, Index 2000', 'Municipal waste treated',
#        'Other disposal', 'Other municipal waste', 'Other recovery',
#        'Recycling', 'Total Incineration', 'Waste from households',
#        'Country_y', 'CO2 emissions (metric tons per capita)',
#        "Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)",
#        "Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)",
#        "Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)",
#        'Energy use (kg of oil equivalent per capita)',
#        'Forest area (sq. km)', 'GDP (constant 2015 US$)',
#        'GDP growth (annual %)', 'GDP per capita (constant 2015 US$)',
#        'GDP per capita growth (annual %)',
#        'Government expenditure on education, total (% of GDP)',
#        'Government expenditure on education, total (% of government expenditure)',
#        'Population density (people per sq. km of land area)',
#        'Population growth (annual %)', 'Population, female',
#        'Population, female (% of total population)', 'Population, total',
#        'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)',
#        'Poverty headcount ratio at national poverty lines (% of population)',
#        'Urban population (% of total population)',
#        'Urban population growth (annual %)'], dtype=object)

# %% [markdown]
# ###### Rename long column names for better readability.

# %%
merged_df = merged_df.rename(columns={'Country_x': 'Country', '% Composting': 'Composting%', '% Disposal': 'Disposal%',\
                                      '% Landfill': 'Landfill%', '% Material recovery (Recycling + Composting)': 'Material_recovery%',\
                                     '% Recovery': 'Recovery%', '% Recycling': 'Recycling%', 'Amount designated for recovery operations': 'Amt_for_recovery_operations',\
                                     'Electric and electronic equipment waste': 'Electronic_waste',\
                                     'Household and similar waste': 'Household_waste', 'Municipal waste generated': 'Municipal_waste_generated',\
                                     'Municipal waste generated per capita': 'Municipal_waste_generated_percapita',\
                                     'Municipal waste generated, Index 1990': 'Municipal_waste_generated_1990',\
                                     'Municipal waste generated, Index 2000': 'Municipal_waste_generated_2000',\
                                     'Municipal waste treated': 'Municipal_waste_treated', 'Total Incineration': 'Total_Incineration',\
                                     'Waste from households': 'Waste_from_households',\
                                     'CO2 emissions (metric tons per capita)':'CO2_emissions_percapita',\
                                     'Educational attainment, at least Bachelor\'s or equivalent, population 25+, female (%) (cumulative)': 'Female_education_attainment_bach',\
                                     'Educational attainment, at least Bachelor\'s or equivalent, population 25+, male (%) (cumulative)': 'Male_education_attainment_bach',\
                                     'Educational attainment, at least Bachelor\'s or equivalent, population 25+, total (%) (cumulative)': 'Total_education_attainment_bach',\
                                     'Energy use (kg of oil equivalent per capita)': 'Energy_use_percapita',\
                                     'Forest area (sq. km)': 'Forest_area',\
                                      'GDP (constant 2015 US$)': 'GDP_2015_USD', 'GDP growth (annual %)': 'GDP_growth%',\
                                      'GDP per capita (constant 2015 US$)': 'GDP_percapita_2015_USD', \
                                      'GDP per capita growth (annual %)': 'GDP_percapita_growth%', 'Government expenditure on education, total (% of GDP)': 'Education_expense_%_of_gdp',\
                                     'Government expenditure on education, total (% of government expenditure)': 'Education_expense_%_of_total_exp',\
                                     'Population density (people per sq. km of land area)': 'Population_density',\
                                     'Population growth (annual %)': 'Population_growth%', 'Population, female': 'Population_female',\
                                     'Population, female (% of total population)': 'Population_female_%', 'Population, total': 'Population_total',\
                                     'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)': 'Poverty_headcount%_ppp',\
                                     'Poverty headcount ratio at national poverty lines (% of population)': 'Poverty_headcount%_national_line',\
                                     'Urban population (% of total population)': 'Population_urban%', 'Urban population growth (annual %)': 'Population_urban_growth%'})

# %% [markdown]
# ###### Drop unnecessary columns.

# %%
clean_df = merged_df.drop(['% Incineration', '% Incineration with energy recovery', '% Incineration without energy recovery',\
                          '% Other disposal', '% Other recovery', 'Bulky waste', 'Disposal operations',\
                           'Incineration with energy recovery', 'Incineration without energy recovery',\
                          'Other disposal', 'Other municipal waste', 'Other recovery'],axis=1)

# %%
clean_df.head()
# Out:
#    Year  COU                       Country  Composting%  Disposal%  Landfill%  \
# 0  1990  AUT                       Austria       23.171     56.277     56.277
# 1  1990  BEL                       Belgium        5.983     66.751     43.853
# 2  1990  CHE                   Switzerland        6.341     22.680     22.680
# 3  1990  CHN  China (People's Republic of)          NaN        NaN        NaN
# 4  1990  DEU                       Germany          NaN        NaN        NaN
#
#    Material_recovery%  Recovery%  Recycling%  Amt_for_recovery_operations  \
# 0              34.529     43.723      11.358                       1536.0
# 1              11.108     33.249       5.125                       1317.0
# 2              28.547     77.320      22.207                       3170.6
# 3                 NaN        NaN         NaN                          NaN
# 4                 NaN        NaN         NaN                          NaN
#
#    ...  Education_expense_%_of_total_exp  Population_density  \
# 0  ...                  11.5131101608276    93.0422927775085
# 1  ...                               NaN                 NaN
# 2  ...                      17.181640625    169.888411039996
# 3  ...                               NaN    120.448249116415
# 4  ...                               NaN    227.517053819494
#
#    Population_growth%  Population_female  Population_female_%  \
# 0   0.762001611316115            4005232     52.1660667580361
# 1   0.298235706313592            5090672     51.0733225104169
# 2    1.02687307219521            3437405     51.1859913754554
# 3    1.46730321087928          552721134     48.6899610599665
# 4   0.861969448764933           41104568     51.7474514630407
#
#    Population_total  Poverty_headcount%_ppp  Poverty_headcount%_national_line  \
# 0           7677850                     NaN                               NaN
# 1           9967379                     NaN                               NaN
# 2           6715519                     NaN                               NaN
# 3        1135185000                      72                               NaN
# 4          79433029                     NaN                               NaN
#
#    Population_urban%  Population_urban_growth%
# 0              62.96         0.332494357748522
# 1             96.377         0.386473447431904
# 2             73.926         0.945758640258411
# 3             26.442          4.30967848070248
# 4             73.118          1.05636514177316
#
# [5 rows x 44 columns]

# %%
clean_df.shape
# Out:
# (1076, 44)

# %% [markdown]
# ### Metadata
# ##### As of now, Pandas does not have a robust method to store metadata, so metadata are stored as comments for reference.
#
# 1.Material_recovery% = (Recycling + Composting)%.
#
# 2.Municipal_waste_generated_1990 = Municipal waste generated, Index 1990.
#
# 3.Municipal_waste_generated_2000 = Municipal waste generated, Index 2000.
#
# 4.Household_waste = in Tonnes.
#
# 5.Waste_from_households = in Tonnes.
#
# 6.CO2_emissions_percapita = metric tons per capita.
#
# 7.Female_education_attainment_bach = Educational attainment, at least Bachelor\'s or equivalent, population 25+, female (%) (cumulative).
#
# 8.Male_education_attainment_bach = Educational attainment, at least Bachelor\'s or equivalent, population 25+, male (%) (cumulative).
#
# 9.Total_education_attainment_bach = Educational attainment, at least Bachelor\'s or equivalent, population 25+, total (%) (cumulative).
#
# 10.Energy_use_percapita = Energy use (kg of oil equivalent per capita).
#
# 11.Forest_area = Forest area (sq. km).
#
# 12.GDP_percapita_2015_USD = GDP (constant 2015 USD).
#
# 13.GDP_percapita_growth = GDP per capita growth (annual %).
#
# 14.Education_expense_%_of_gdp = Government expenditure on education, total (% of GDP).
#
# 15.Education_expense_%_of_total_exp = Government expenditure on education, total (% of government expenditure).
#
# 16.Population_density = Population density (people per sq. km of land area).
#
# 17.Population_growth% = Population growth (annual %).
#
# 18.Poverty_headcount%_ppp = Poverty headcount ratio at $2.15 a day (2017 PPP, \% of population).
#
# 19.Poverty_headcount\%_national_line = Poverty headcount ratio at national poverty lines (\% of population).
#
# 20.Population_urban\% = Urban population (\% of total population).
#
# 21.Population_urban_growth\% = Urban population growth (annual \%).
#
# 22.GDP_2015_USD = GDP (constant 2015 US$).
#
# 23.GDP_growth% = GDP growth (annual %).
#
# ##### Note:
#
# 1.Some variables are measuring the same thing but with different values like Household_waste and Waste_from_households. No clear difference is known at this point.
#
# 2.Due to differences in spellings, abbreviations of names etc., there are 2 country columns (one from each dataframe). For now, we will keep both and remove later if one proves better for graphs etc.

# %%
clean_df.columns
# Out:
# Index(['Year', 'COU', 'Country', 'Composting%', 'Disposal%', 'Landfill%',
#        'Material_recovery%', 'Recovery%', 'Recycling%',
#        'Amt_for_recovery_operations', 'Composting', 'Electronic_waste',
#        'Household_waste', 'Landfill', 'Municipal_waste_generated',
#        'Municipal_waste_generated_percapita', 'Municipal_waste_generated_1990',
#        'Municipal_waste_generated_2000', 'Municipal_waste_treated',
#        'Recycling', 'Total_Incineration', 'Waste_from_households', 'Country_y',
#        'CO2_emissions_percapita', 'Female_education_attainment_bach',
#        'Male_education_attainment_bach', 'Total_education_attainment_bach',
#        'Energy_use_percapita', 'Forest_area', 'GDP_2015_USD', 'GDP_growth%',
#        'GDP_percapita_2015_USD', 'GDP_percapita_growth%',
#        'Education_expense_%_of_gdp', 'Education_expense_%_of_total_exp',
#        'Population_density', 'Population_growth%', 'Population_female',
#        'Population_female_%', 'Population_total', 'Poverty_headcount%_ppp',
#        'Poverty_headcount%_national_line', 'Population_urban%',
#        'Population_urban_growth%'],
#       dtype='object')

# %% [markdown]
# ###### Check dtypes and convert where necessary.

# %%
clean_df.dtypes
# Out:
# Year                                     int64
# COU                                     object
# Country                                 object
# Composting%                            float64
# Disposal%                              float64
# Landfill%                              float64
# Material_recovery%                     float64
# Recovery%                              float64
# Recycling%                             float64
# Amt_for_recovery_operations            float64
# Composting                             float64
# Electronic_waste                       float64
# Household_waste                        float64
# Landfill                               float64
# Municipal_waste_generated              float64
# Municipal_waste_generated_percapita    float64
# Municipal_waste_generated_1990         float64
# Municipal_waste_generated_2000         float64
# Municipal_waste_treated                float64
# Recycling                              float64
# Total_Incineration                     float64
# Waste_from_households                  float64
# Country_y                               object
# CO2_emissions_percapita                 object
# Female_education_attainment_bach        object
# Male_education_attainment_bach          object
# Total_education_attainment_bach         object
# Energy_use_percapita                    object
# Forest_area                             object
# GDP_2015_USD                            object
# GDP_growth%                             object
# GDP_percapita_2015_USD                  object
# GDP_percapita_growth%                   object
# Education_expense_%_of_gdp              object
# Education_expense_%_of_total_exp        object
# Population_density                      object
# Population_growth%                      object
# Population_female                       object
# Population_female_%                     object
# Population_total                        object
# Poverty_headcount%_ppp                  object
# Poverty_headcount%_national_line        object
# Population_urban%                       object
# Population_urban_growth%                object
# dtype: object

# %%
cc.convert_dtype(clean_df,['Female_education_attainment_bach','Male_education_attainment_bach','Total_education_attainment_bach',\
                       'GDP_growth%','GDP_percapita_growth%','Education_expense_%_of_gdp',\
                        'Education_expense_%_of_total_exp','GDP_percapita_2015_USD', 'GDP_2015_USD',\
                       'Population_growth%', 'Population_female_%', 'Poverty_headcount%_ppp',\
                       'Poverty_headcount%_national_line', 'Population_urban%', 'Population_urban_growth%',\
                       'CO2_emissions_percapita', 'Energy_use_percapita', 'Forest_area', 'Population_density'],\
                       ['Population_female', 'Population_total'],\
                       ['COU', 'Country','Country_y'])
# Out:
# Year                                     int64
# COU                                     string
# Country                                 string
# Composting%                            float64
# Disposal%                              float64
# Landfill%                              float64
# Material_recovery%                     float64
# Recovery%                              float64
# Recycling%                             float64
# Amt_for_recovery_operations            float64
# Composting                             float64
# Electronic_waste                       float64
# Household_waste                        float64
# Landfill                               float64
# Municipal_waste_generated              float64
# Municipal_waste_generated_percapita    float64
# Municipal_waste_generated_1990         float64
# Municipal_waste_generated_2000         float64
# Municipal_waste_treated                float64
# Recycling                              float64
# Total_Incineration                     float64
# Waste_from_households                  float64
# Country_y                               string
# CO2_emissions_percapita                float64
# Female_education_attainment_bach       float64
# Male_education_attainment_bach         float64
# Total_education_attainment_bach        float64
# Energy_use_percapita                   float64
# Forest_area                            float64
# GDP_2015_USD                           float64
# GDP_growth%                            float64
# GDP_percapita_2015_USD                 float64
# GDP_percapita_growth%                  float64
# Education_expense_%_of_gdp             float64
# Education_expense_%_of_total_exp       float64
# Population_density                     float64
# Population_growth%                     float64
# Population_female                        int64
# Population_female_%                    float64
# Population_total                         int64
# Poverty_headcount%_ppp                 float64
# Poverty_headcount%_national_line       float64
# Population_urban%                      float64
# Population_urban_growth%               float64
# dtype: object

# %% [markdown]
# ##### Summary statistics

# %%
clean_df.describe()
# Out:
#               Year  Composting%   Disposal%   Landfill%  Material_recovery%  \
# count  1076.000000   823.000000  924.000000  941.000000          895.000000
# mean   2006.182156    10.035549   54.526934   51.038226           28.228668
# std       8.148865     8.606104   33.765836   33.736434           18.682200
# min    1990.000000     0.000000    0.000000    0.000000            0.000000
# 25%    2000.000000     2.272000   20.620500   17.279000           11.073000
# 50%    2006.000000     8.157000   57.793000   56.032000           28.951000
# 75%    2013.000000    15.854000   86.447500   81.459000           43.017500
# max    2020.000000    38.928000  100.026000  100.000000           74.958000
#
#         Recovery%  Recycling%  Amt_for_recovery_operations    Composting  \
# count  907.000000  858.000000                   947.000000    850.000000
# mean    46.221372   19.819824                  8492.724430   1653.250229
# std     33.546255   12.563997                 18699.744875   3406.294148
# min      0.000000    0.000000                     0.000000      0.000000
# 25%     15.534500    9.717500                   372.465000     52.030000
# 50%     42.388000   20.580500                  2088.480000    327.470000
# 75%     80.016500   27.287000                  5808.590000   1596.775000
# max    100.000000   61.569000                132666.000000  24485.000000
#
#        Electronic_waste  ...  Education_expense_%_of_total_exp  \
# count        248.000000  ...                        759.000000
# mean         282.322476  ...                         12.948282
# std         1240.460039  ...                          3.222039
# min            0.000000  ...                          5.828970
# 25%            3.960000  ...                         10.668070
# 50%           14.985000  ...                         12.603190
# 75%           91.000000  ...                         15.145275
# max         9045.000000  ...                         30.151421
#
#        Population_density  Population_growth%  Population_female  \
# count         1055.000000         1076.000000       1.076000e+03
# mean           133.739952            0.571099       3.605072e+07
# std            126.291488            0.742970       1.025608e+08
# min              2.277313           -2.258464       1.333210e+05
# 25%             35.595962            0.135649       2.629984e+06
# 50%            107.069264            0.513604       5.367950e+06
# 75%            172.666617            1.070990       2.983851e+07
# max            530.377275            2.890960       6.794869e+08
#
#        Population_female_%  Population_total  Poverty_headcount%_ppp  \
# count          1076.000000      1.076000e+03              681.000000
# mean             51.001522      7.233000e+07                1.792952
# std               1.077556      2.104025e+08                6.027218
# min              47.983044      2.674680e+05                0.000000
# 25%              50.412186      5.185058e+06                0.100000
# 50%              50.852385      1.040006e+07                0.300000
# 75%              51.391928      5.814972e+07                0.900000
# max              54.210582      1.396215e+09               72.000000
#
#        Poverty_headcount%_national_line  Population_urban%  \
# count                        353.000000        1076.000000
# mean                          16.238810          74.034459
# std                            5.086451          12.533740
# min                            3.100000          26.442000
# 25%                           12.700000          67.155750
# 50%                           15.600000          75.472500
# 75%                           19.500000          82.627000
# max                           49.800000          98.079000
#
#        Population_urban_growth%
# count               1076.000000
# mean                   0.913130
# std                    1.023103
# min                   -2.282468
# 25%                    0.308390
# 50%                    0.810591
# 75%                    1.566850
# max                    4.601685
#
# [8 rows x 41 columns]

# %%
clean_df.isnull().sum()
# Out:
# Year                                     0
# COU                                      0
# Country                                  0
# Composting%                            253
# Disposal%                              152
# Landfill%                              135
# Material_recovery%                     181
# Recovery%                              169
# Recycling%                             218
# Amt_for_recovery_operations            129
# Composting                             226
# Electronic_waste                       828
# Household_waste                        763
# Landfill                                98
# Municipal_waste_generated               31
# Municipal_waste_generated_percapita     96
# Municipal_waste_generated_1990         540
# Municipal_waste_generated_2000         111
# Municipal_waste_treated                104
# Recycling                              190
# Total_Incineration                     258
# Waste_from_households                  477
# Country_y                                0
# CO2_emissions_percapita                 24
# Female_education_attainment_bach       900
# Male_education_attainment_bach         900
# Total_education_attainment_bach        900
# Energy_use_percapita                   179
# Forest_area                             11
# GDP_2015_USD                             2
# GDP_growth%                              9
# GDP_percapita_2015_USD                   2
# GDP_percapita_growth%                    9
# Education_expense_%_of_gdp             267
# Education_expense_%_of_total_exp       317
# Population_density                      21
# Population_growth%                       0
# Population_female                        0
# Population_female_%                      0
# Population_total                         0
# Poverty_headcount%_ppp                 395
# Poverty_headcount%_national_line       723
# Population_urban%                        0
# Population_urban_growth%                 0
# dtype: int64

# %% [markdown]
# ##### Export final dataframe to csv for future use

# %%
clean_df.to_csv('clean_df.csv')
